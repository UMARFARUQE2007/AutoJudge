# %%
import pandas as pd
import re
from sklearn.preprocessing import LabelEncoder

# %%
try:
    df = pd.read_json('problems_data.jsonl', lines=True)
except ValueError:
    print("Error: check filetype again")
    exit()

# %%
df = df.dropna(subset=['problem_score', 'problem_class'])
le = LabelEncoder()
df['difficulty_label'] = le.fit_transform(df['problem_class'])
class_mapping = {k: int(v) for k, v in zip(le.classes_, le.transform(le.classes_))} #int(v) so int64 doesn't come
print("Mapping:", class_mapping) #yo remember hard is 1
text_columns = ['title', 'description', 'input_description', 'output_description']
for col in text_columns:
    df[col] = df[col].fillna('')

df['combined_text'] = (
    df['title'] + " " + 
    df['description'] + " " + 
    df['input_description'] + " " + 
    df['output_description']
)

def upd(text):
    text = text.lower()
    text = re.sub(r'<.*?>', '', text)
    text = " ".join(text.split())
    return text

df['combined_text'] = df['combined_text'].apply(upd)
# Out:
# Mapping: {'easy': 0, 'hard': 1, 'medium': 2}

# %%
hard_topics = [
    'convex hull', 'mobius', 'segment tree', 'flow', 'centroid', 
    'geometry', 'gcd', 'mex', 'dynamic programming', 
    'modulo', 'bitwise', 'graph', 'expected value','permutations','xor','shortest path','grid','query','range','range query'
]
for j in range(len(hard_topics)):
    topic = hard_topics[j]
    col_name = f'has_{topic.replace(" ", "_")}'
    df[col_name] = df['combined_text'].str.contains(topic, case=False).astype(int)  

df['hard_topic_count'] = 0
for j in range(len(hard_topics)):
    topic = hard_topics[j]
    df['hard_topic_count'] += df['combined_text'].str.contains(topic, case=False).astype(int)
    
                                                                            
df['is_short_statement'] = (df['combined_text'].str.len() < 300).astype(int)
df['text_len'] = df['combined_text'].apply(len)
mathsym = ['$', '^', '{', '}', '_', '\\', '=', '<', '>','*']
df['math_count'] = 0
for j in range(len(mathsym)):
    sym = mathsym[j]
    df['math_count'] += df['combined_text'].str.count(re.escape(sym))
df['has_high_constraints'] = df['combined_text'].str.contains(r'10\^5|10\^9|1000000007|1e9|1e5', regex=True).astype(int)
df['math_density'] = df['math_count'] / (df['combined_text'].str.len() + 1)

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text

def get_class_probs(df):
    classes = [0, 1, 2] 
    class_data = {}
    
    for cls in classes:
        subset = df[df['difficulty_label'].isin([cls, str(cls)])]['combined_text'].dropna()
        
        if len(subset) == 0:
            print(f"Warning: No data found for class {cls}. Skipping...")
            class_data[str(cls)] = {}
            continue
            
        vec = CountVectorizer(binary=True, token_pattern=r"(?u)\b\w+\b")
        try:
            matrix = vec.fit_transform(subset)
            probs = matrix.sum(axis=0).A1 / len(subset)
            class_data[str(cls)] = dict(zip(vec.get_feature_names_out(), probs))
        except ValueError:
            class_data[str(cls)] = {}
            
    return class_data

probs = get_class_probs(df)
all_words = set(probs['0'].keys()) | set(probs['1'].keys()) | set(probs['2'].keys())
feature_scores = []

for word in all_words:
    p0 = probs['0'].get(word, 0)
    p1 = probs['1'].get(word, 0) 
    p2 = probs['2'].get(word, 0) 
    
    spread = max(p0, p1, p2) - min(p0, p1, p2)
    is_noise = (p0 > 0.25 and p1 > 0.25 and p2 > 0.25)
    feature_scores.append({'word': word, 'spread': spread, 'is_noise': is_noise})

features_df = pd.DataFrame(feature_scores)
new_cp_stopwords = features_df[features_df['is_noise'] == True]['word'].tolist()
print(new_cp_stopwords)
cp_manual_stop = [
    'input', 'output', 'line', 'number', 'integer', 'integers', 
    'problem', 'given', 'contains', 'possible', 'single', 'test', 
    'case', 'cases', 'print', 'outputting', 'standard', 'format', 'program', 'write', 'le', 'leq', 'consists', 'help',
    'containing', 'contain', 'time', 'giving', 'following', 'exactly','completely','satisfy','loves','love',
]

merged_stopwords = list(set(cp_manual_stop).union(set(new_cp_stopwords)))
final_stopwords = list(text.ENGLISH_STOP_WORDS.union(merged_stopwords))


tfidf = TfidfVectorizer(
    max_features=3000, 
    stop_words=final_stopwords, 
    ngram_range=(1, 2)
)

X_tfidf = tfidf.fit_transform(df['combined_text'])
hard_dist = probs['1']
med_dist = probs['2']
easy_dist = probs['0']
mediumvec = []
hardvec = []
for word, prob in hard_dist.items():
    if word in final_stopwords:
        continue
    p_m = med_dist.get(word, 0)
    p_e = easy_dist.get(word, 0)
    if prob > 2*p_m:
        hardvec.append((word, prob))

for word, prob in med_dist.items():
    if word in final_stopwords:
        continue
    p_h = hard_dist.get(word, 0)
    p_e = easy_dist.get(word, 0)
    if prob > 2*p_h:
        mediumvec.append((word, prob))
print(len(hardvec))
hardvec.sort(key=lambda x: x[1], reverse=True)
# print("Top 15 Hard-Only Signals:")
# for word, prob in hardvec[:15]:
#     print(f"{word}: {prob:.4f}")
hard_keywords = [word for word, prob in hardvec[:30]] # Take the top 20
mediumvec.sort(key=lambda x: x[1], reverse=True)
medium_keywords = [word for word, prob in mediumvec[:30]]

df['high_difficulty_signal_count'] = df['combined_text'].apply(
    lambda x: sum(1 for word in hard_keywords if word in x.lower())
)
df['medium_signal_count'] = df['combined_text'].apply(
    lambda x: sum(1 for word in medium_keywords if word in x.lower())
)
X_manual = df[['hard_topic_count', 'math_density', 'text_len', 'high_difficulty_signal_count','is_short_statement','has_high_constraints','medium_signal_count']].values
X_manual[:, -1] *= 5 
Xf = sp.hstack((X_tfidf, X_manual))

print("Feature Matrix Shape:", Xf.shape)
# Out:
# ['be', 'input', 's', 'a', 'when', 'single', 'in', 'or', 'it', 'at', 'for', 'that', 'can', 'but', 'and', 'most', 'your', 'integers', '1', 'you', 'containing', '2', 'by', 'integer', 'number', 'are', 'first', 'how', 'is', 'given', '10', 'le', 'n', 'on', 'contains', 'there', 'where', 'to', 'this', 'one', '000', '0', 'consists', 'output', 'line', 'no', 'so', 'as', 'then', 'leq', 'if', 'which', 'order', 'all', 'not', 'two', 'with', 'up', 'should', 'from', 'lines', 'the', 'they', 'has', 'each', 'an', 'will', 't', 'have', 'only', 'of']
# 8384
# Feature Matrix Shape: (4112, 3007)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    Xf, 
    df['difficulty_label'], 
    test_size=0.3, 
    random_state=7,   #rerun doesn't changes it
    stratify=df['difficulty_label']  #maintain a good ratio
)

print(f" on {X_train.shape[0]} problems...")
# Out:
#  on 2878 problems...

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.decomposition import TruncatedSVD

pipe = Pipeline([
    ('svd', TruncatedSVD(n_components=700, random_state=7)),
    ('clf', RandomForestClassifier(oob_score=True, random_state=7))
])

param_grid = {
    'svd__n_components': [100, 200],
    'clf__n_estimators': [200, 500],
    'clf__max_features': ['sqrt', 0.2],
    'clf__max_depth': [None, 30],
    'clf__min_samples_leaf': [1, 3],
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=7)
gs = GridSearchCV(pipe, param_grid, cv=cv, n_jobs=-1, scoring='accuracy', verbose=2)
gs.fit(X_train, y_train)
print("Best params:", gs.best_params_)
print("CV score:", gs.best_score_)
best = gs.best_estimator_
y_pred = best.predict(X_test)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.6s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.6s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.8s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   3.8s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   3.9s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   4.0s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.1s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.2s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   6.4s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   6.4s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.2s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   5.8s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.2s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.0s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.1s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   8.3s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   8.7s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   8.4s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   5.4s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   5.5s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   5.5s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.3s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.2s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   7.4s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   7.6s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.1s
# [CV] END clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   7.6s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   8.3s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   8.4s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   8.6s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  10.9s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.3s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  11.1s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  11.1s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.0s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.0s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   7.8s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   7.8s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   7.9s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   9.7s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  21.0s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  21.0s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.4s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=  10.2s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.6s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  21.1s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   2.5s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   3.5s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   9.8s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   3.6s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   3.5s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   6.1s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   6.4s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=   6.5s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.6s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.7s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   9.0s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  19.5s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  19.6s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   8.9s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   2.3s
# [CV] END clf__max_depth=None, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  19.7s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.5s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.5s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   3.7s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=   9.4s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   6.2s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   6.1s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=   6.5s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.7s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.9s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   8.6s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   8.5s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=100; total time=   4.9s
# [CV] END clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=   8.6s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   9.1s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   9.2s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=200, svd__n_components=200; total time=   9.1s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  11.0s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.0s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.0s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  11.1s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=100; total time=  11.4s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=100; total time=   4.0s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   8.7s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   8.8s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=200, svd__n_components=200; total time=   9.0s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=  11.6s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  22.9s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  22.9s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=  11.9s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=1, clf__n_estimators=500, svd__n_components=200; total time=  23.3s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=100; total time=  11.1s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  17.5s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  17.3s
# [CV] END clf__max_depth=30, clf__max_features=0.2, clf__min_samples_leaf=3, clf__n_estimators=500, svd__n_components=200; total time=  16.0s
# Best params: {'clf__max_depth': 30, 'clf__max_features': 0.2, 'clf__min_samples_leaf': 1, 'clf__n_estimators': 500, 'svd__n_components': 200}
# CV score: 0.5076425095585679

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(
    n_estimators=500, 
    max_features=0.2, 
    class_weight='balanced_subsample', 
    min_samples_leaf=1,              
    oob_score=True,
    random_state=7,
)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(f"Out of Bag Score: {clf.oob_score_:.4f}")
print("\n")
print(f"Test Accuracy: {clf.score(X_test, y_test):.4f}")
print("\n")
print(f"Model Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print("\n")
print(classification_report(y_test, y_pred, target_names=le.classes_))
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Classification Confusion Matrix')
plt.show()
# Out:
# Out of Bag Score: 0.5049
#
#
# Test Accuracy: 0.5259
#
#
# Model Accuracy: 0.53
#
#
#               precision    recall  f1-score   support
#
#         easy       0.47      0.35      0.40       230
#         hard       0.58      0.74      0.65       582
#       medium       0.44      0.33      0.38       422
#
#     accuracy                           0.53      1234
#    macro avg       0.49      0.47      0.47      1234
# weighted avg       0.51      0.53      0.51      1234
